# %%
import pandas as pd

# %%
data = pd.read_csv("../ai_skepticism_dataset.csv")
data
# Out:
#     ai_model_name     query_category  ai_confidence_percentage  \
# 0          Claude   math_calculation                     93.23
# 1           Llama     recipe_cooking                     84.47
# 2          Claude  general_knowledge                     69.82
# 3          Claude   creative_writing                     79.61
# 4          Claude   creative_writing                     67.71
# ..            ...                ...                       ...
# 995        Gemini   math_calculation                     94.09
# 996         Llama   financial_advice                     62.60
# 997        Claude   technical_coding                     77.38
# 998   ChatGPT-3.5   math_calculation                     98.61
# 999         Llama      opinion_based                     55.61
#
#      response_character_count  has_cited_sources  contains_hedging_words  \
# 0                         527               True                   False
# ...

# %%
data_type = type(data)
data_type
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h4>Understanding the data</h4>

# %% [markdown]
# <h5> 1. Checking no.of rows and columns present in the dataset</h5>

# %%
data.shape
# Out:
# (1000, 23)

# %% [markdown]
# <h5>2. Checking the Structure of dataset</h5>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ai_model_name               1000 non-null   object
#  1   query_category              1000 non-null   object
#  2   ai_confidence_percentage    1000 non-null   float64
#  3   response_character_count    1000 non-null   int64
#  4   has_cited_sources           1000 non-null   bool
#  5   contains_hedging_words      1000 non-null   bool
#  6   includes_disclaimer         1000 non-null   bool
#  7   answer_detail_level         1000 non-null   object
#  8   respondent_age_bracket      1000 non-null   object
#  9   education_level             1000 non-null   object
#  10  digital_literacy_score      1000 non-null   object
#  11  ai_familiarity_level        1000 non-null   object
#  12  decision_importance         1000 non-null   object
# ...

# %% [markdown]
# <h5>3. Checking whether any null values present in the dataset </h5>

# %%
df.isnull().sum()  # you can also use any() for checking the null values
# Out:
# ai_model_name                   0
# query_category                  0
# ai_confidence_percentage        0
# response_character_count        0
# has_cited_sources               0
# contains_hedging_words          0
# includes_disclaimer             0
# answer_detail_level             0
# respondent_age_bracket          0
# education_level                 0
# digital_literacy_score          0
# ai_familiarity_level            0
# decision_importance             0
# urgency_level                 221
# belief_alignment_status       342
# subject_matter_expertise        0
# trust_score_out_of_10           0
# performed_fact_check            0
# fact_check_method_used        372
# verification_duration_mins      0
# answer_accuracy_percentage      0
# trust_calibration_valid         0
# user_skepticism_category        0
# dtype: int64

# %% [markdown]
# <h5>4. Handling the missing values</h5>

# %%
data['urgency_level'].fillna("Unknown")
data['belief_alignment_status'].fillna("Unknown")
data['fact_check_method_used'].fillna("Unknown")

# %% [markdown]
# <h5>5. Checking Duplicates</h5>
# <h6>If any duplicates exist use drop_duplicates()</h6>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h5>6. Checking the unique values</h5>

# %%
data['ai_model_name'].unique()
data["query_category"].unique()
data["education_level"].unique()
# Out:
# array(['claude', 'llama', 'mistral', 'chatgpt-3.5', 'gemini', 'gpt-4'],
#       dtype=object)

# %% [markdown]
# <h5>7. Fixing the values</h5>

# %%
data['ai_model_name'] = data['ai_model_name'].str.upper().str.strip()
data['ai_model_name']
# Out:
# 0           CLAUDE
# 1            LLAMA
# 2           CLAUDE
# 3           CLAUDE
# 4           CLAUDE
#           ...
# 995         GEMINI
# 996          LLAMA
# 997         CLAUDE
# 998    CHATGPT-3.5
# 999          LLAMA
# Name: ai_model_name, Length: 1000, dtype: object

# %% [markdown]
# <h5>8. Checking the Outliers</h5>

# %%
df.describe()
# Out:
#        ai_confidence_percentage  response_character_count  \
# count               1000.000000               1000.000000
# mean                  72.006790                429.022000
# std                   14.663334                221.644937
# min                   40.520000                 50.000000
# 25%                   60.570000                239.500000
# 50%                   74.235000                423.000000
# 75%                   83.862500                629.000000
# max                   98.660000                799.000000
#
#        trust_score_out_of_10  verification_duration_mins  \
# count            1000.000000                 1000.000000
# mean                7.905000                   14.840000
# std                 1.766866                   15.182336
# min                 1.800000                    0.000000
# 25%                 6.700000                    0.000000
# 50%                 8.200000                   11.050000
# ...
